# %% [markdown]
# # Magrathea Map Rendering Playground
#
# Use this notebook to interactively develop and test the rendering engine.
# Changes to `src/magrathea/maps/rendering_engine.py` will be automatically reloaded.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

from magrathea.maps.rendering_engine import generate_heightmap

# Configure matplotlib to display inline
# %matplotlib inline

# %%
# Parameters
size = 256
octaves = 4
seed = 42
island_density = 0.0

# Generate Map
heightmap = generate_heightmap(
    size=size, octaves=octaves, seed=seed, island_density=island_density
)

# Visualize
plt.figure(figsize=(10, 10))
plt.imshow(heightmap, cmap="terrain", origin="upper", vmin=0, vmax=1)
plt.colorbar(label="Elevation")
plt.title(f"Map Seed: {seed}")
plt.axis("off")
plt.show()
# Out:
# 2026-01-05 18:32:35.006 | DEBUG    | magrathea.maps.rendering_engine:generate_heightmap:2 - Generating heightmap: size=256, octaves=4, seed=42, density=0.0

# %% [markdown]
# #
